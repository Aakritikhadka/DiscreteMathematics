# %% [markdown]
# Project Part # 4: CPSMA 3913
# Discrete Mathematics
# Aakriti Khadka
# Dr. Jacob

# %% [markdown]
# For this project, I will choose different post cards of football players from the bucket of players card which will consists of 10 different
# football players Ronaldo, Messi, Ronaldinho, Pele, Kaka, Neymar, Maradona, Dembele, Suarez, Buffon as my 10 events.

# %%
player_cards=['Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Maradona', 'Dembele', 'Suarez', 'Buffon']
len(player_cards)
# Out:
# 10

# %% [markdown]
# For this project I have 10 different events which results to having 10 different possible outcomes. x^n

# %%
10**10
# Out:
# 10000000000

# %% [markdown]
# If order did not matter there will be following outcomes that would bepossible in my simulation

# %%
import math

math.factorial(15)/(math.factorial(10)*math.factorial(5))
# Out:
# 3003.0

# %% [markdown]
# Using Replacement

# %%
from itertools import combinations_with_replacement

combWithReplacement = list(combinations_with_replacement(player_cards,5))
print(combWithReplacement)
# Out:
# [('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldinho'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Pele'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Kaka'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Neymar'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Maradona'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Dembele'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Suarez'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Ronaldo', 'Buffon'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Messi'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Ronaldinho'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Pele'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Kaka'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Neymar'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Maradona'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Dembele'), ('Ronaldo', 'Ronaldo', 'Ronaldo', 'Messi', 'Suarez'), 
# ...

# %%
len(combWithReplacement)
# Out:
# 2002

# %% [markdown]
# Without Replacement -- if order matters

# %%
print(math.factorial(10))
# Out:
# 3628800

# %%
math.factorial(10)/(math.factorial(0)*math.factorial(10))
# Out:
# 1.0

# %%
from itertools import combinations
combination = list(combinations(player_cards,8))
print(combination)
# Out:
# [('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Maradona', 'Dembele'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Maradona', 'Suarez'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Maradona', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Dembele', 'Suarez'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Dembele', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Neymar', 'Suarez', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Maradona', 'Dembele', 'Suarez'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Maradona', 'Dembele', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Maradona', 'Suarez', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Kaka', 'Dembele', 'Suarez', 'Buffon'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Neymar', 'Maradona', 'Dembele', 'Suarez'), ('Ronaldo', 'Messi', 'Ronaldinho', 'Pele', 'Neymar', 'Maradona', 'Dembel
# ...

# %% [markdown]
# For the last question, I used binomial expression. As given we need to find the 5th order of the of (x-3)^9. We have the formula,
# $$
# (x+y)^n = \sum_{k=0}^n {n\choose{k}} x^{n-k} y^k
# $$

# %% [markdown]
# $$
# (x-3)^9 = \binom{9}{0} x^9(-3)^0 + \binom{8}{1} x^8(-3)^1 + \binom{7}{2} x^7(-3)^2 + \binom{6}{3} x^6(-3)^3 + \binom{5}{4} x^5(-3)^4 + \binom{4}{5} x^4(-3)^5 + \binom{3}{6} x^3(-3)^6 + \binom{2}{7} x^2(-3)^7 + \binom{1}{8} x^1(-3)^8 + \binom{0}{9} x^0(-3)^9
# $$

# %% [markdown]
# $$
# \binom{5}{0} x^5(-3)^0 + \binom{4}{1} x^4(-3)^1 + \binom{3}{2} x^3(-3)^2 + \binom{2}{3} x^2(-3)^3 + \binom{1}{4} x^1(-3)^4 + \binom{0}{5} x^0(-3)^5 \\ = \ x^5 - 12x^4 + 27x^3
# $$

# %% [markdown]
# In the below equation from implementing binomial expresion we can see that the coefficient of x^5 is 1,
# $$
# x^5 - 12x^4 + 27x^3
# $$

# %% [markdown]
# To conclude, we found the coefficient of x^5 to be 1. I found this project to be little complex and hard than the rest of other. But it was nice to know about different libraries that I used in this project.
