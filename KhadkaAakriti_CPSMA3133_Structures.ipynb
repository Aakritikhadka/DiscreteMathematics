# %% [markdown]
# Project Module 5: Structures
#
# CPSMA 3133
#
# Dr. Jacob's Discrete Mathematics
#
# Aakriti Khadka, 269021

# %%
import graphviz
soccer = graphviz.Digraph('Soccer')


# played for Manchester 
#heading
soccer.node('Z','Soccer')

#different leagues
soccer.node('A','Primere League')
soccer.node('B','LaLiga')
soccer.node('C','SerieA')
soccer.node('D','Ligue1')
soccer.node('Y','Bundesliga')

#different clubs
soccer.node('E','Manchester United')

soccer.node('I','Real Madrid')
soccer.node('F','Ronaldo')
soccer.node('H','DiMaria')

soccer.node('J','Barcelona')
soccer.node('G','Messi')
soccer.node('K','Argentina')

soccer.node('M','Juventus')

soccer.node('Q','PSG')


soccer.node('U','Bayern Munich')


#relationship between leagues and clubs
soccer.edges(['ZA','ZB','ZC','ZD','ZY','AE','BI','BJ','CM','DQ','YU','IF','IH','JG','EF','QG','HK','GK'])
soccer

# %% [markdown]
# I first liked football then I discovered different leagues of football. I loved watching Ronaldo and Messi.
# I got interested in Laliga and Primere League and I was the fan of Manchester United and Barcelona.  Ronaldo played for
# Manchester United and Messi for Barcelona so I followed them. Later Ronaldo switched to Real Madrid so I followed Real Madrid
# and Ronaldo and Messi to PSG. I liked DiMaria from RealMadrid. Later I knoe DiMaria and Messi played for same national team
# Argentina

# %% [markdown]
# The degree of each vertex shows how I became influenced in watching soccer. The degree of each vertex shows how i moved from one club to the different clubs. PSG: 1, Bundesliga: 1. The degree of vertex represA cycle is a closed trail where start vertex is equal to end vertex like Ronaldo, Argentina.
